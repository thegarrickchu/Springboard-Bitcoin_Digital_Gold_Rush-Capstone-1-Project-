# %% [markdown]
# #### Exploration 4) Examining possible relationships among popular cryptocurrencies (Ether, Iota, Litecoin and Ripple)

# %%
import pandas as pd
import glob
import numpy as np

path = r'''C:\Users\Garrick\Documents\Springboard\Capstone Project 1\BTC_Datasets_vol2'''
filenames = list(glob.glob(path + "\*.csv"))
file = filenames[0]

crypt_ex = pd.read_csv(file, parse_dates=['Date'], index_col='Date')
crypt_ex.columns = [x+"_"+file[-10:-4] for x in crypt_ex.columns]
for file in filenames[1:]:
    load = pd.read_csv(file, parse_dates=['Date'], index_col='Date')
    load.columns = [x+"_"+file[-10:-4] for x in load.columns]
    crypt_ex = pd.merge(crypt_ex, load, left_index=True, right_index=True)

crypt_ex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 201 entries, 2018-01-11 to 2017-06-13
# Data columns (total 35 columns):
# High_BTCUSD      201 non-null float64
# Low_BTCUSD       201 non-null float64
# Mid_BTCUSD       201 non-null float64
# Last_BTCUSD      201 non-null float64
# Bid_BTCUSD       201 non-null float64
# Ask_BTCUSD       201 non-null float64
# Volume_BTCUSD    201 non-null float64
# High_ETHUSD      201 non-null float64
# Low_ETHUSD       201 non-null float64
# Mid_ETHUSD       201 non-null float64
# Last_ETHUSD      201 non-null float64
# Bid_ETHUSD       201 non-null float64
# Ask_ETHUSD       201 non-null float64
# Volume_ETHUSD    201 non-null float64
# High_IOTUSD      201 non-null float64
# Low_IOTUSD       201 non-null float64
# Mid_IOTUSD       201 non-null float64
# Last_IOTUSD      201 non-null float64
# Bid_IOTUSD       201 non-null float64
# Ask_IOTUSD       201 non-null float64
# Volume_IOTUSD    201 non-null float64
# ...

# %% [markdown]
# 1/11/18 Data Dictionary:
#
# All datasets are for that cryptocurrency in USD and includes daily low, high, bid, ask and volume.
#
# BTC = Bitcoin
#
# ETH = Ethereum
#
# IOT = Iota
#
# LTC = Litecoin
#
# XRP = Ripple
#
# Iota was launched in June 2017 and thus the dataframe only includes data starting for when Iota was introduced.
# (May be better for analysis to exclude Iota dataset)

# %%
crypt_ex.describe()
# Out:
#         High_BTCUSD    Low_BTCUSD    Mid_BTCUSD  Last_BTCUSD    Bid_BTCUSD  \
# count    201.000000    201.000000    201.000000    201.00000    201.000000
# mean    6325.070207   5741.859276   6104.556468   6104.32073   6103.718905
# std     4568.798811   3997.748273   4360.454731   4360.15774   4359.905815
# min     2051.100000   1826.200000   1949.350000   1950.00000   1949.200000
# 25%     2902.200000   2694.400000   2841.950000   2844.90000   2838.000000
# 50%     4430.000000   4175.000000   4351.950000   4352.00000   4351.900000
# 75%     7440.000000   6911.000000   7126.450000   7126.40000   7126.400000
# max    19891.000000  18622.000000  19209.000000  19210.00000  19208.000000
#
#          Ask_BTCUSD  Volume_BTCUSD  High_ETHUSD   Low_ETHUSD   Mid_ETHUSD  \
# count    201.000000     201.000000   201.000000   201.000000   201.000000
# mean    6105.394030   45885.397490   378.685025   340.734826   362.847338
# ...

# %%
# plotting the Crypto pricing data to visualize

import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline
plt.style.use('bmh')

font = {'family' : 'sans-serif',
        'weight' : 'medium',
        'size'   : 16}

matplotlib.rc('font', **font)

crypt_ex.plot(subplots=True, figsize=(20,100))
plt.show()

# %% [markdown]
# Though it seems there is a dramatic increase across the board in the above coins, it is difficult to say for certain that there is a correlation between the price performances.
#
# Let us use a scatterplot method to visualize potential correlations in greater detail.

# %%
# subplotting only volume and Mid-price per coin

mids = ['Mid_BTCUSD','Mid_ETHUSD','Mid_IOTUSD','Mid_LTCUSD','Mid_XRPUSD']
vols = ['Volume_BTCUSD','Volume_ETHUSD','Volume_IOTUSD','Volume_LTCUSD','Volume_XRPUSD']

both = [j for i in zip(mids,vols) for j in i]

crypt_ex[both].plot(subplots=True, figsize=(20,40))
plt.show()

# %%
pd.plotting.scatter_matrix(crypt_ex[['Mid_BTCUSD','Mid_ETHUSD','Mid_IOTUSD','Mid_LTCUSD','Mid_XRPUSD']], diagonal="kde",
                            figsize=(20,20), alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# We do not see any clear correlations among the coin prices.  Let us examine Volume.  Perhaps activity in one coin affects the activity in another?

# %%
pd.plotting.scatter_matrix(crypt_ex[['Volume_BTCUSD','Volume_ETHUSD','Volume_IOTUSD','Volume_LTCUSD','Volume_XRPUSD']], diagonal="kde",
                            figsize=(20,20), alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# As in price, no clear correlation is found among coin volumes.
#
# Since we are given bid/ask data, I also wish to explore daily spread within each coin's market.  In capital markets, the spread is the value difference between a bidder's price and the seller's ask.  Theoretically, informationally efficient and liquid markets should see very little spread.  As a result, some will analyze spread as a proxy for volatility (higher spread can indicate dissonance in the market).

# %%
# creating new columns for daily inter-coin spread
crypt_ex['Spread_BTC'] = crypt_ex.Ask_BTCUSD.sub(crypt_ex.Bid_BTCUSD)
crypt_ex['Spread_ETH'] = crypt_ex.Ask_ETHUSD.sub(crypt_ex.Bid_ETHUSD)
crypt_ex['Spread_IOT'] = crypt_ex.Ask_IOTUSD.sub(crypt_ex.Bid_IOTUSD)
crypt_ex['Spread_LTC'] = crypt_ex.Ask_LTCUSD.sub(crypt_ex.Bid_LTCUSD)
crypt_ex['Spread_RIP'] = crypt_ex.Ask_XRPUSD.sub(crypt_ex.Bid_XRPUSD)

# %%
pd.plotting.scatter_matrix(crypt_ex[['Spread_BTC','Spread_ETH','Spread_IOT','Spread_LTC','Spread_RIP']], diagonal="kde",
                            figsize=(20,20), alpha=1)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Exploration 3) Analysis:
#
# Through our visual exploration of our data, it seems there may be some relationships between price and volume of coins (essentially intra-market dynamics).   However, the inter-coin spread does not appear to affect the other. This can be interpreted as, the volatility and market price risk in one coin does not appear to incite of affect price volatility in others.

# %% [markdown]
# #### Exploration 3b)  Statistical exploration of cryptocurrencies
#
# Objectives:
#
# *Quantify/confirm the correlations and relationships that are suggested by the visualizations
#
# *Assess viability of using this data in a ML model

# %%
# outputting values of correlation between coin prices

px_corr = crypt_ex[['Mid_BTCUSD','Mid_ETHUSD','Mid_IOTUSD','Mid_LTCUSD','Mid_XRPUSD']].corr()
print(px_corr)
# Out:
#             Mid_BTCUSD  Mid_ETHUSD  Mid_IOTUSD  Mid_LTCUSD  Mid_XRPUSD
# Mid_BTCUSD    1.000000    0.831611    0.921704    0.899781    0.625674
# Mid_ETHUSD    0.831611    1.000000    0.840506    0.891562    0.879821
# Mid_IOTUSD    0.921704    0.840506    1.000000    0.906808    0.672821
# Mid_LTCUSD    0.899781    0.891562    0.906808    1.000000    0.737545
# Mid_XRPUSD    0.625674    0.879821    0.672821    0.737545    1.000000

# %%
import seaborn as sns
sns.heatmap(px_corr, square=True, annot=True,)
plt.title('Cryptocurrency Price Correlations')
plt.show()

# %%
# outputting values of correlation between coin volumes

vol_corr = crypt_ex[['Volume_BTCUSD','Volume_ETHUSD','Volume_IOTUSD','Volume_LTCUSD','Volume_XRPUSD']].corr()
print(vol_corr)
# Out:
#                Volume_BTCUSD  Volume_ETHUSD  Volume_IOTUSD  Volume_LTCUSD  \
# Volume_BTCUSD       1.000000       0.618239       0.556679       0.629883
# Volume_ETHUSD       0.618239       1.000000       0.392737       0.558947
# Volume_IOTUSD       0.556679       0.392737       1.000000       0.392757
# Volume_LTCUSD       0.629883       0.558947       0.392757       1.000000
# Volume_XRPUSD       0.262252       0.344295       0.290177       0.296894
#
#                Volume_XRPUSD
# Volume_BTCUSD       0.262252
# Volume_ETHUSD       0.344295
# Volume_IOTUSD       0.290177
# Volume_LTCUSD       0.296894
# Volume_XRPUSD       1.000000

# %% [markdown]
# We see there are indeed very strong correlations between the coin prices and medium to weak correlations volumes.  However, if proceeding with implementing a Machine Learning Model may choose to keep volume in as a feature.

# %% [markdown]
# The underlying curiosity I had set out to explore is whether we can predict Bitcoin prices based on the activity in other coins.  At this point, I wish to employ recently learned concepts in Machine Learning using scikit-learn on this coin data.  I want to see if it is possible to predict Bitcoin prices or not.  The outcome of either case would be insightful.
#
# In this case, I will be using SciKit-Learn's Lasso Linear Regression as I do not know which features to include and to what degree.  Therefore, will be relying on Regularization via Lasso.
#
# Furthermore, I wish to apply a scaling method here to account for the different units of scale for each feature.

# %%
# importing essential libraries for modeling

from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.linear_model import Lasso, LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
# creating inputs necessary for the models

col_list = ['Mid_ETHUSD','Mid_IOTUSD','Mid_LTCUSD','Mid_XRPUSD', 'Volume_BTCUSD',
            'Volume_ETHUSD','Volume_IOTUSD','Volume_LTCUSD','Volume_XRPUSD']  #omitting MID_BTC as it is our target

X = crypt_ex[col_list]
y = crypt_ex.Mid_BTCUSD.values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=16)

# %%
# instantiating and fitting the model

scaler = StandardScaler()
lasso  = Lasso(alpha=0.6)

pipeline = make_pipeline(scaler, lasso)
lasso_scaled = pipeline.fit(X_train, y_train)

# %%
# plotting the coefs of the features computed by the lasso model

lasso_coef = lasso.coef_

plt.bar(range(len(X.columns)), lasso_coef, align='center')
plt.xticks(range(len(X.columns)), X.columns.values, rotation=60)
plt.margins(0.02)
plt.show()
print(lasso_coef)
# Out:
# [-5994.65350138  2533.74080493   340.71234115  3117.80750845
#  -1078.72280215  -754.96420253   645.86289355    39.84250213
#    701.33445179]

# %%
lasso_scaled.score(X_test, y_test)
# Out:
# 0.8939525925902057

# %%
x_new = np.array([[1115.85, 2.2765, 163.35, 1.1269, 43450, 136162, 6582122, 145831 , 68250520]]) # jan 31 data

# yesterday's BTC mid price was 10,192

lasso_scaled.predict(x_new)
# Out:
# array([13866.65355907])

# %%
x_new2 = np.array([[981.91, 2.5098, 177.83, 1.3299, 63857, 227914, 13140109, 204099 , 162534798]]) # Jan 24 data

# jan 24 BTC mid price = 10,827
lasso_scaled.predict(x_new2)
# Out:
# array([14356.676973])

# %% [markdown]
# According to the Lasso model, the price of Litecoin, Ripple, and Ethereum volumes are the most significant features in predicting the price of Bitcoin, Y.  The model also has an accuracy of 89.4% given the test data.  However, the predict values come relatively close (in the grand scheme) but not quite on the mark.  The prediction dates are only separated by a week, but I found that subtracting ~$3,500 off the prediction I can get quite close.
#
# Let's try as a normal linear regression since we only have limited features.

# %%
linreg = LinearRegression()

pipeline2 = make_pipeline(scaler, linreg)

linreg_scaled = pipeline2.fit(X_train, y_train)

# %%
linreg_scaled.score(X_test, y_test)
# Out:
# 0.8937526514048075

# %%
lin_coef = linreg.coef_

plt.bar(range(len(X.columns)), lin_coef, align='center')
plt.xticks(range(len(X.columns)), X.columns.values, rotation=60)
plt.margins(0.02)
plt.xlabel('Covariates')
plt.ylabel('Weighting')
plt.show()
print(lin_coef)
# Out:
# [1124.24479543 1183.19786008 2003.24959162 -466.98346427 1165.97208689
#  -656.07854129  527.5787587  -299.1075124   330.87288616]

# %%
linreg_scaled.predict(x_new)
# yesterday's BTC mid price was 10,192
# Out:
# array([13886.25039987])

# %%
# jan 24 BTC mid price = 10,827
linreg_scaled.predict(x_new2)
# Out:
# array([14369.96006567])

# %% [markdown]
# Given the similar correlation proportions as in the Lasso model, it is unsurprising that the regular Linear Model performs similarly to the Lasso.
#
# In both cases, the model is able to acheive an 89% accuracy on the testing data.  However, they appear to really miss the mark in the newer unseen data.  I noticed that subtracing 3,500 from the prediction brings the prediction closer to the actual value.  This may indicate that the model is missing one or more features which may help it improve.

# %%
# lets try using lagged variables... for example, can we predict with yesterday/last week/last month's data?
X_shift_day = X.shift(periods=1)
X_shift_day.fillna(0, inplace=True)
X_train, X_test, y_train, y_test = train_test_split(X_shift_day, y, test_size = 0.3, random_state=16)

lasso_day = pipeline.fit(X_train, y_train)
lasso_day.score(X_test, y_test)
# Out:
# 0.701677066491438

# %%
X_shift_month = X.shift(periods=30)
X_shift_month.fillna(0, inplace=True)
X_train, X_test, y_train, y_test = train_test_split(X_shift_month, y, test_size = 0.3, random_state=16)

lasso_month = pipeline.fit(X_train, y_train)
lasso_month.score(X_test, y_test)
# Out:
# 0.4018311007083265

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(X)
plt.show()

# %% [markdown]
# Using a lag of one day and one month did not improve our accuracy or indicate we can predict based on this frequency... Is there another time period that I may have missed?
#
# Per the above Autocorrelation plot, it appears there is no other frequency to use (which would have been indicated by the blue line going above or below the bounds of the dotted line).
